# %%
import matplotlib.pyplot as plt 

x = [1,2,3,4]
y = [1,2.5,3.5,3]

# %% [markdown]
# loc: left, center, right

# %%
plt.plot(x,y)
plt.xlabel("X label")
plt.ylabel("Y label")

config = {"size":15,"color":"blue"}
plt.title("test",config,loc="right")
# Out:
# Text(1.0, 1.0, 'test')

# %%
plt.show()
