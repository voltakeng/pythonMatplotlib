# %%
import matplotlib.pyplot as plt 

x = [1,2,3,4]
y = [1,2.5,3.5,3]

# %%
plt.plot(x,y)

plt.xlabel("X label",size=20,color="red",backgroundcolor="yellow")

data = {"size":20,"color":"red","backgroundcolor":"yellow"}
plt.ylabel("Y label",data)

plt.show()
